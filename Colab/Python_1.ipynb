# %% [markdown]
# ### Что это?
#
# Это платформа Google Colab. Она позволяет писать и запускать код на Python прямо в браузере. Интерпретатор при этом используется от гугла. Тут бывает удобно тестировать нейронные сети, делиться кодом и заметками.
# Для начала попробуем выполнить простую программу вывода.

# %%
print("Hello, Colab!")
# Out:
# Hello, Colab!

# %% [markdown]
# Пока до самого питона мы еще не добрались, поэтому данный раздел будет отредактирован позднее 👨🏼‍💻
